# %% [markdown]
# <a href="https://colab.research.google.com/github/sushankindroji/Men-Stylist/blob/main/Men_Stylist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Details:
    def __init__(self, gender="", height=0, weight=0, chest=0, waist=0, upperbodylength=0, lowerbodylength=0):
        self.gender = gender
        self.height = height
        self.weight = weight
        self.chest = chest
        self.waist = waist
        self.upperbodylength = upperbodylength
        self.lowerbodylength = lowerbodylength

class SizeChartOfShirts(Details):
    def __init__(self, chest, waist, upperbodylength):
        super().__init__(chest=chest, waist=waist, upperbodylength=upperbodylength)
        if self.chest >= 32 and self.chest < 35 and self.waist >= 28 and self.waist < 30 and self.upperbodylength == 25:
            self.size = "XS"
        elif self.chest >= 35 and self.chest < 37 and self.waist >= 30 and self.waist < 32 and self.upperbodylength == 26:
            self.size = "S"
        elif self.chest >= 37 and self.chest < 40 and self.waist >= 32 and self.waist < 34 and self.upperbodylength == 27:
            self.size = "M"
        elif self.chest >= 40 and self.chest < 43 and self.waist >= 34 and self.waist < 36 and self.upperbodylength == 28:
            self.size = "L"
        elif self.chest >= 43 and self.chest < 46 and self.waist >= 36 and self.waist < 38 and self.upperbodylength == 29:
            self.size = "XL"
        else:
            self.size = "Shirt size is not compatible"

    def print_size(self):
        print("\n\nShirt size:", self.size)
        return self.size

class SizeChartOfTrousers(Details):
    def __init__(self, waist, lowerbodylength):
        super().__init__(waist=waist, lowerbodylength=lowerbodylength)
        if self.waist >= 28 and self.waist < 30 and self.lowerbodylength == 40:
            self.size = "XS"
        elif self.waist >= 30 and self.waist < 32 and self.lowerbodylength == 41:
            self.size = "S"
        elif self.waist >= 32 and self.waist < 34 and self.lowerbodylength == 42:
            self.size = "M"
        elif self.waist >= 34 and self.waist < 36 and self.lowerbodylength == 43:
            self.size = "L"
        elif self.waist >= 36 and self.waist < 38 and self.lowerbodylength == 44:
            self.size = "XL"
        else:
            self.size = "Trousers size is not compatible"

    def print_size(self):
        print("Trousers size:", self.size)
        return self.size

class MyStylist:

    def determine_body_type(self, shirt_size, trouser_size):
        if shirt_size in ["XS", "S"] and trouser_size in ["XS", "S"]:
            self.btype="Ectomorph"
        elif shirt_size in ["S", "M"] and trouser_size in ["M", "L"]:
            self.btype="Mesomorph"
        elif shirt_size in ["L", "XL"] and trouser_size == "XL":
            self.btype="Endomorph"
        else:
            self.btype="Undetermined"
    def bodytypee(self):
        print("body typee is:",self.btype)
        return self.btype

    def suggest_occasion_outfit(self, occasion):
        print("\n\nOccasion:", occasion)


# Based on the occasion,bodytype suggested outfit combinations are here
import random
class outfitcombinations:
    def outfit(self):
        if selected_occasion in [1, 2, 3, 4]:
            if bodytypeee == "Ectomorph":
                self.shirt = random.choice(["White t-shirt", "Gray crew neck sweater", "Navy blue button-down shirt", "Striped polo shirt", "Olive green henley",
                                           "Black long sleeve t-shirt", "Light blue denim shirt", "Maroon v-neck tee", "Tan linen button-up", "Charcoal gray ribbed tank top"])
                self.trouser = random.choice(["Khaki chinos", "Dark wash skinny jeans", "Olive green cargo pants", "Gray slim-fit joggers", "Navy blue dress pants",
                                             "Beige linen trousers", "Black stretch twill pants", "Tan relaxed-fit shorts", "Light wash denim jeans", "Olive green utility pants"])
                self.shoe = random.choice(["White low-top sneakers", "Brown suede chukka boots", "Black leather loafers", "Gray canvas slip-on shoes", "Tan leather boat shoes",
                                           "Navy blue low-top Converse", "Brown leather derby shoes", "Beige espadrilles", "Black leather Chelsea boots", "Gray mesh running shoes"])
                self.accessory = random.choice(["Black baseball cap", "Brown leather belt", "Aviator sunglasses", "Brown leather watch", "Navy blue wool scarf",
                                               "Silver pendant necklace", "Tan woven bracelet", "Tortoiseshell wayfarer glasses", "Brown leather messenger bag", "Gray knit beanie"])
            elif bodytypeee=="Mesomorph":
                self.shirt=random.choice(["White crew neck t-shirt", "Navy blue polo shirt", "Gray v-neck sweater", "Burgundy button-down shirt", "Black athletic henley",
                                          "Olive green lightweight jacket", "Heather gray graphic tee", "Tan linen short-sleeve shirt", "Blue and white striped tee",
                                          "Charcoal gray long sleeve shirt"])
                self.trouser= random.choice(["Dark wash bootcut jeans", "Khaki chino shorts", "Olive green cargo pants", "Gray slim-fit dress pants", "Navy blue jogger sweatpants",
                                            "Light wash distressed denim", "Beige relaxed-fit chinos", "Black stretch twill trousers", "Brown corduroy pants",
                                            "Charcoal gray wool trousers"])
                self.shoe=random.choice(["White leather sneakers", "Brown suede desert boots", "Black leather dress shoes", "Navy blue canvas boat shoes", "Gray mesh running shoes",
                                        "Tan leather loafers", "Olive green combat boots", "Brown leather wingtips", "Blue suede low-top Chucks", "Black leather Chelsea boots"])
                self.accessory= random.choice(["Snapback baseball cap", "Braided brown leather belt", "Mirrored aviator sunglasses", "Stainless steel watch", "Burgundy knit scarf",
                                              "Silver chain necklace", "Black leather messenger bag", "Green and brown woven bracelet", "Tortoiseshell square frames",
                                              "Maroon and gray striped beanie"])
            elif bodytypeee=="Endomorph":
                self.shirt=random.choice(["Navy blue t-shirt", "Gray button-down shirt", "Maroon v-neck sweater", "White polo shirt", "Black lightweight jacket",
                                          "Olive green henley", "Light blue denim shirt", "Striped crew neck tee", "Brown linen shirt", "Charcoal gray sweatshirt"])
                self.trouser= random.choice(["Khaki relaxed-fit chinos", "Dark wash bootcut jeans", "Gray sweatpants", "Navy blue dress pants", "Tan linen trousers",
                                            "Black cotton joggers", "Olive green cargo pants", "Brown corduroy pants", "Light wash straight leg jeans", "Charcoal gray wool trousers"])
                self.shoe=random.choice(["Brown leather boots", "Black leather loafers", "Gray suede derby shoes", "Navy blue canvas sneakers", "Tan leather boat shoes",
                                        "Brown suede chukka boots", "Black leather dress shoes", "Olive green combat boots", "Burgundy leather wingtips", "Gray mesh athletic shoes"])
                self.accessory= random.choice(["Newsboy cap in olive", "Woven brown leather belt", "Polarized wayfarer sunglasses", "Leather-banded wrist watch",
                                              "Burgundy and navy plaid scarf", "Pendant necklace in silver", "Brown leather messenger bag", "Beige canvas tote bag",
                                              "Tortoiseshell round glasses", "Gray knit touchscreen gloves"])
        elif selected_occasion in [5, 6, 7, 8]:
            if bodytypeee=="Ectomorph":
                self.shirt=random.choice(["White cotton kurta", "Navy blue Nehru collar shirt", "Mustard yellow printed tunic", "Olive green embroidered shirt",
                                          "Maroon textured short kurta", "Cream linen long sleeve shirt", "Indigo blue denim long kurta", "Gray lightweight sherwani jacket",
                                          "Teal green printed button-down", "Black and gold embroidered Mandarin collar shirt"])
                self.trouser=random.choice(["Beige relaxed-fit linen pants", "Navy blue slim-fit churidar", "Gray herringbone wool trousers", "Olive green straight-leg chinos",
                                            "White cotton drawstring pants", "Charcoal gray pleated palazzo", "Tan relaxed-fit jute trousers", "Blue denim slim-fit jeans",
                                            "Burgundy corduroy straight-leg", "Black cotton jogger pants"])
                self.shoe=random.choice(["Brown leather mojari", "Black leather dress shoes", "Tan suede Espadrilles", "Navy blue canvas juttis", "Gray suede desert boots",
                                        "Olive green leather Kolhapuri", "Beige linen slip-on shoes", "Burgundy leather monk straps", "Brown leather penny loafers",
                                        "Black leather Oxfords"])
                self.accessory=random.choice(["Indigo blue turban", "Silver metal kada bracelet", "Beige linen pocket square", "Gold tone pendant necklace",
                                              "Burgundy and gold silk scarf", "Wooden bead and leather bracelet", "Tortoiseshell square sunglasses", "Brown leather messenger bag",
                                              "Mustard yellow pashmina shawl", "Silver and onyx stud earrings"])
            elif bodytypeee=="Mesomorph":
                self.shirt=random.choice(["White cotton Kurta", "Navy blue Nehru collar shirt", "Maroon printed short Kurta", "Olive green embroidered Sherwani",
                                          "Gray lightweight Achkan jacket", "Mustard yellow textured Tunic", "Teal green long sleeve Kurta", "Indigo blue denim Kurta",
                                          "Black and gold Mandarin collar shirt", "Cream linen Kaftan top"])
                self.trouser= random.choice(["Brown leather Mojari", "Black leather Dress shoes", "Olive green leather Kolhapuri", "Tan suede Espadrilles",
                                            "Navy blue canvas Juttis", "Burgundy leather Monk straps", "Brown leather penny Loafers", "Black leather Oxfords",
                                            "Gray suede Desert boots", "Beige linen slip-on Shoes"])
                self.shoe=random.choice(["Brown leather Mojari", "Black leather Dress shoes", "Olive green leather Kolhapuri", "Tan suede Espadrilles", "Navy blue canvas Juttis",
                                        "Burgundy leather Monk straps", "Brown leather penny Loafers", "Black leather Oxfords", "Gray suede Desert boots", "Beige linen slip-on Shoes"])
                self.accessory= random.choice(["Maroon and gold Turban", "Silver metal Kada bracelet", "Mustard yellow Pashmina shawl", "Gold tone pendant Necklace",
                                              "Teal and burgundy silk Scarf", "Wooden bead and leather Bracelet", "Tortoiseshell square Sunglasses", "Brown leather Messenger bag",
                                              "Indigo and white printed Pocket square", "Silver and onyx stud Earrings"])
            elif bodytypeee=="Endomorph":
                self.shirt=random.choice(["White linen Kurta", "Navy blue printed Tunic", "Maroon textured Sherwani", "Olive green embroidered Shirt",
                                          "Charcoal gray Nehru collar jacket", "Mustard yellow long sleeve Kurta", "Teal green relaxed-fit Kaftan", "Indigo blue denim Kurta",
                                          "Black and gold Mandarin collar shirt", "Cream cotton printed Shirt"])
                self.trouser= random.choice(["Beige relaxed-fit Linen pants", "Navy blue pleated Churidar", "Olive green straight-leg Chinos", "Charcoal gray drawstring Palazzo",
                                            "White cotton loose Pajamas", "Tan relaxed-fit Jute trousers", "Burgundy corduroy straight-leg", "Black cotton Jogger pants",
                                            "Dark wash bootcut Jeans", "Gray herringbone Wool trousers"])
                self.shoe=random.choice(["Brown leather Mojari", "Black leather Dress shoes", "Olive green leather Kolhapuri", "Tan suede Desert boots", "Navy blue canvas Juttis",
                                        "Burgundy leather Monk straps", "Brown leather penny Loafers", "Black leather Oxfords", "Gray suede Espadrilles", "Beige linen slip-on Shoes"])
                self.accessory= random.choice(["Burgundy and gold turban", "Silver metal Kada bracelet", "Mustard yellow Pashmina shawl", "Gold tone pendant Necklace",
                                              "Teal and navy silk Scarf", "Wooden bead and leather Bracelet", "Tortoiseshell round Sunglasses", "Brown leather Messenger bag",
                                              "Indigo and white printed Pocket square", "Silver and onyx stud Earrings"])
        elif selected_occasion in [9, 10, 11, 12]:
            if bodytypeee=="Ectomorph":
                self.shirt=random.choice(["White cotton dress shirt", "Light blue pinstripe button-up", "Lavender textured dress shirt", "Navy blue spread collar shirt",
                                          "Gray herringbone button-down", "Cream linen long sleeve shirt", "Burgundy twill dress shirt", "Charcoal gray Oxford cloth shirt",
                                          "Light pink spread collar blouse", "Black cotton poplin shirt"])
                self.trouser=random.choice(["Charcoal gray wool trousers", "Tan relaxed-fit dress pants", "Navy blue slim-fit suit pants", "Olive green stretch chinos",
                                            "Medium gray pinstripe slacks", "Black cotton twill trousers", "Beige linen dress pants", "Midnight blue wool trousers",
                                            "Light gray flannel trousers", "Dark brown corduroy pants"])
                self.shoe=random.choice(["Black cap-toe Oxfords", "Brown leather wingtips", "Black patent leather loafers", "Tan suede dress boots", "Navy blue leather derbies",
                                        "Burgundy leather brogues", "Gray leather monk straps", "Black suede chukka boots", "Brown leather penny loafers",
                                        "Olive green canvas dress shoes"])
                self.accessory=random.choice(["Navy blue silk necktie", "Black leather dress belt", "Cream linen pocket square", "Silver tie clip", "Burgundy knit wool scarf",
                                              "Black leather document case", "Tortoiseshell square glasses", "Gold cufflinks with onyx", "Brown leather briefcase",
                                              "Gray wool felt fedora"])
            elif bodytypeee=="Mesomorph":
                self.shirt=random.choice(["White cotton dress shirt", "Light blue pinstripe button-up", "Navy blue spread collar shirt", "Charcoal gray herringbone shirt",
                                          "Maroon textured dress shirt", "Olive green Oxford cloth shirt", "Lavender point collar blouse", "Black cotton poplin shirt",
                                          "Cream linen long sleeve shirt", "Burgundy twill dress shirt"])
                self.trouser= random.choice(["Charcoal gray wool trousers", "Navy blue slim-fit suit pants", "Medium gray pinstripe slacks", "Tan relaxed-fit dress pants",
                                            "Black cotton twill trousers", "Olive green stretch chinos", "Midnight blue wool trousers", "Beige linen dress pants",
                                            "Light gray flannel trousers", "Dark brown corduroy pants"])
                self.shoe=random.choice(["Black cap-toe Oxfords", "Brown leather wingtips", "Burgundy leather brogues", "Black patent leather loafers", "Tan suede dress boots",
                                        "Navy blue leather derbies", "Gray leather monk straps", "Brown leather penny loafers", "Black suede chukka boots",
                                        "Olive green canvas dress shoes"])
                self.accessory= random.choice(["Navy blue silk necktie", "Black leather dress belt", "Maroon knit wool scarf", "Silver tie clip", "Cream linen pocket square",
                                              "Brown leather briefcase", "Tortoiseshell square glasses", "Gold cufflinks with onyx", "Black leather document case",
                                              "Gray wool felt fedora"])
            elif bodytypeee=="Endomorph":
                self.shirt=random.choice(["White cotton dress shirt", "Light blue point collar shirt", "Navy blue spread collar shirt", "Charcoal gray pinstripe shirt",
                                          "Maroon textured dress shirt", "Olive green Oxford cloth shirt", "Cream linen long sleeve shirt", "Black cotton poplin shirt",
                                          "Burgundy twill dress shirt", "Lavender broadcloth blouse"])
                self.trouser= random.choice(["Charcoal gray wool trousers", "Navy blue pleated dress pants", "Medium gray pinstripe slacks", "Tan relaxed-fit dress pants",
                                            "Black cotton twill trousers", "Olive green stretch chinos", "Midnight blue wool trousers", "Beige linen dress pants",
                                            "Dark brown corduroy pants", "Light gray flannel trousers"])
                self.shoe=random.choice(["Black cap-toe Oxfords", "Brown leather wingtips", "Burgundy leather brogues", "Black leather loafers", "Tan suede dress boots",
                                        "Navy blue leather derbies", "Gray leather monk straps", "Brown leather penny loafers", "Black leather Oxfords",
                                        "Olive green canvas dress shoes"])
                self.accessory= random.choice(["Navy blue silk necktie", "Black leather dress belt", "Burgundy knit wool scarf", "Silver tie clip", "Cream linen pocket square",
                                              "Brown leather briefcase", "Tortoiseshell round glasses", "Gold cufflinks with onyx", "Black leather document case",
                                              "Gray wool felt fedora"])
        elif selected_occasion in [13, 14, 15, 16]:
            if bodytypeee=="Ectomorph":
                self.shirt=random.choice(["Gray lightweight moisture-wicking t-shirt", "Navy blue breathable long sleeve top", "White perforated performance tank",
                                          "Olive green lightweight zip-up jacket", "Charcoal gray ribbed athletic henley", "Bright blue quick-dry short sleeve tee",
                                          "Black loose-fit workout tank", "Light gray moisture-wicking base layer", "Teal green breathable running shirt",
                                          "Burgundy compression athletic shirt"])
                self.trouser=random.choice(["Black lightweight running shorts", "Navy blue slim-fit athletic joggers", "Heather gray moisture-wicking leggings",
                                            "Olive green stretch training pants", "White loose-fit workout sweatpants", "Charcoal gray compression tights",
                                            "Burgundy moisture-wicking track pants", "Tan lightweight hiking pants", "Dark green water-resistant windbreaker",
                                            "Light blue relaxed-fit jersey shorts"])
                self.shoe=random.choice(["White mesh running sneakers", "Black leather cross-training shoes", "Gray knit slip-on athletic shoes", "Navy blue canvas high-top sneakers",
                                        "Olive green trail running shoes", "Teal green lightweight walking shoes", "Charcoal gray breathable gym shoes",
                                        "Light blue knit athletic slip-ons", "White and red structured running shoes", "Maroon suede indoor training shoes"])
                self.accessory=random.choice(["Black quick-dry performance headband", "Neon yellow reflective running vest", "Navy blue polyester moisture-wicking socks",
                                              "Olive green adjustable workout gloves", "Charcoal gray silicone smart watch", "Maroon microfiber gym/yoga towel",
                                              "Teal green lightweight drawstring backpack", "White and blue striped fitness resistance band",
                                              "Black mesh-paneled reusable water bottle", "Burgundy moisture-wicking exercise sweatband"])
            elif bodytypeee=="Mesomorph":
                self.shirt=random.choice(["Navy blue breathable performance tee", "Charcoal gray moisture-wicking tank top", "White lightweight athletic long sleeve",
                                          "Olive green zip-up training jacket", "Bright red quick-dry workout shirt", "Black compression athletic base layer",
                                          "Teal blue perforated workout singlet", "Maroon ribbed athletic muscle shirt", "Light gray seamless knit training top",
                                          "Burgundy short sleeve performance polo"])
                self.trouser= random.choice(["Black lightweight running shorts", "Navy blue slim-fit athletic joggers", "Heather gray moisture-wicking leggings",
                                            "Olive green stretch training pants", "Charcoal gray compression tights", "White loose-fit workout sweatpants",
                                            "Burgundy moisture-wicking track pants", "Dark green water-resistant windbreaker", "Light blue relaxed-fit jersey shorts",
                                            "Tan lightweight hiking pants"])
                self.shoe=random.choice(["White mesh running sneakers", "Black leather cross-training shoes", "Navy blue canvas high-top sneakers", "Olive green trail running shoes",
                                        "Teal green lightweight walking shoes", "Charcoal gray breathable gym shoes", "Light blue knit athletic slip-ons",
                                        "White and red structured running shoes", "Maroon suede indoor training shoes", "Gray knit slip-on athletic shoes"])
                self.accessory= random.choice(["Navy blue polyester moisture-wicking socks", "Neon yellow reflective running vest", "Olive green adjustable workout gloves",
                                              "Charcoal gray silicone smart watch", "Maroon microfiber gym/yoga towel", "Teal green lightweight drawstring backpack",
                                              "White and blue striped fitness resistance band", "Black mesh-paneled reusable water bottle",
                                              "Burgundy moisture-wicking exercise sweatband", "Black quick-dry performance headband"])
            elif bodytypeee=="Endomorph":
                self.shirt=random.choice(["Navy blue breathable performance tee", "Charcoal gray moisture-wicking tank top", "White lightweight athletic long sleeve",
                                          "Olive green zip-up training jacket", "Maroon ribbed athletic muscle shirt", "Black compression athletic base layer",
                                          "Light gray seamless knit training top", "Burgundy short sleeve performance polo", "Dark green quick-dry workout shirt",
                                          "Royal blue perforated workout singlet"])
                self.trouser= random.choice(["Black lightweight athletic shorts", "Navy blue relaxed-fit workout joggers", "Charcoal gray compression training tights",
                                            "Olive green stretch training pants", "White loose-fit workout sweatpants", "Burgundy moisture-wicking track pants",
                                            "Dark green water-resistant windbreaker", "Light blue relaxed-fit jersey shorts", "Tan lightweight hiking pants",
                                            "Heather gray athletic training pants"])
                self.shoe=random.choice(["Black leather cross-training shoes", "Navy blue canvas high-top sneakers", "Olive green trail running shoes",
                                        "Charcoal gray breathable gym shoes", "Light blue knit athletic slip-ons", "White and red structured running shoes",
                                        "Maroon suede indoor training shoes", "Gray knit slip-on athletic shoes", "White mesh running sneakers",
                                        "Teal green lightweight walking shoes"])
                self.accessory= random.choice(["Navy blue polyester moisture-wicking socks", "Neon yellow reflective running vest", "Olive green adjustable workout gloves",
                                              "Charcoal gray silicone smart watch", "Maroon microfiber gym/yoga towel", "Teal green lightweight drawstring backpack",
                                              "White and blue striped fitness resistance band", "Black mesh-paneled reusable water bottle",
                                              "Burgundy moisture-wicking exercise sweatband", "Black quick-dry performance headband"])


    def print_outfits(self):
        print("Shirt :", self.shirt)
        print("Trousers :", self.trouser)
        print("shoes would be :", self.shoe)
        print("wearable accessory :", self.accessory)


# Input body configurations
print("Enter body configurations")
gender = input("Gender (M/F): ")
height = float(input("Height (in feet): "))
chest = float(input("Chest size (in inches): "))
waist = float(input("Waist size (in inches): "))
upperbodylength = float(input("Upper body length (in inches): "))
lowerbodylength = ((int(height)*12)+((height*10)-(int(height)*10)))-upperbodylength
print("Lower body length (in inches):", lowerbodylength)

# Determine shirt and trousers sizes
person_shirt = SizeChartOfShirts(chest, waist, upperbodylength)
shirt_size = person_shirt.print_size()
person_trousers = SizeChartOfTrousers(waist, lowerbodylength)
trouser_size = person_trousers.print_size()

# Instantiate MyStylist class
stylist = MyStylist()


# Determine body type
stylist.determine_body_type(shirt_size, trouser_size)
bodytypeee=stylist.bodytypee()

# Suggest occasion outfit
occasions = {
    1: "Weekend outings", 2: "Casual gatherings with friends", 3: "Casual dinners or lunches", 4: "Shopping",
    5: "Traditional ceremonies (weddings, festivals, religious celebrations)", 6: "Cultural events and performances",
    7: "Family gatherings or reunions with traditional themes", 8: "Ethnic restaurants or cultural fairs",
    9: "Business meetings and conferences", 10: "Job interviews", 11: "Formal dinners or galas",
    12: "Award ceremonies or corporate events",13: "Gym workouts or exercise classes", 14: "Sports activities (jogging, biking, hiking)",
    15: "Casual outdoor events", 16: "Traveling or commuting"}

if bodytypeee!="Undetermined":
  print("\n\nLet's get dressed")
  print("choose an occasion for desired attire\n\n")
  print(occasions)
  selected_occasion = int(input("\nSelect occasion index from the dictionary: "))
  stylist.suggest_occasion_outfit(occasions[selected_occasion])
  print("\nrecommended outfit is here")
  for i in range(2):
    print("\n")
    model=outfitcombinations()
    model.outfit()
    model.print_outfits()
# Out:
# Enter body configurations
# Gender (M/F): M
# Height (in feet): 5.9
# Chest size (in inches): 38
# Waist size (in inches): 32
# Upper body length (in inches): 27
# Lower body length (in inches): 42.0
#
#
# Shirt size: M
# Trousers size: M
# body typee is: Mesomorph
#
#
# Let's get dressed
# choose an occasion for desired attire
#
#
# {1: 'Weekend outings', 2: 'Casual gatherings with friends', 3: 'Casual dinners or lunches', 4: 'Shopping', 5: 'Traditional ceremonies (weddings, festivals, religious celebrations)', 6: 'Cultural events and performances', 7: 'Family gatherings or reunions with traditional themes', 8: 'Ethnic restaurants or cultural fairs', 9: 'Business meetings and conferences', 10: 'Job interviews', 11: 'Formal dinners or galas', 12: 'Award ceremonies or corporate events', 13: 'Gym workouts or exercise classes', 14: 'Sports activities (jogging, biking, hiking)', 15: 'Casual outdoor events', 16: 'Traveling or commuting'}
#
# Select occasion index from the dictionary: 2
#
# ...
